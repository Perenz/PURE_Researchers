# %%
import pandas as pd

# %%
pure_researchers = pd.read_excel("../data/pure_researchers.xls")
pure_researchers.head()
# Out:
#                  1 Name 2 Name > First name 3 Name > Last name  \
# 0        R. Abdel Kader                  R.        Abdel Kader
# 1           Tauseef Ali            Tauseef                 Ali
# 2             Robin Aly               Robin                Aly
# 3  Juan Amiguet-Vercher                Juan    Amiguet-Vercher
# 4        N.L.G. Anciaux              N.L.G.            Anciaux
#
#          11.1 Organisations > Organisational unit[1]  \
# 0  Databases (Former) - Former organisational uni...
# 1  Datamanagement & Biometrics - Former organisat...
# 2  Databases (Former) - Former organisational uni...
# 3  Databases (Former) - Former organisational uni...
# 4  Databases (Former) - Former organisational uni...
#
#          11.2 Organisations > Organisational unit[2]  \
# 0                                                NaN
# 1  Services, Cybersecurity & Safety - Former orga...
# 2  Human Media Interaction - Former organisationa...
# 3                                                NaN
# 4                                                NaN
#
#          11.3 Organisations > Organisational unit[3]  \
# 0                                                NaN
# 1  Services, Cybersecurity & Safety - Former orga...
# 2  Databases (Former) - Former organisational uni...
# 3                                                NaN
# 4                                                NaN
#
#          11.4 Organisations > Organisational unit[4]  \
# 0                                                NaN
# 1  Services, Cybersecurity & Safety - Former orga...
# 2  Databases (Former) - Former organisational uni...
# 3                                                NaN
# 4                                                NaN
#
#          11.5 Organisations > Organisational unit[5]  \
# 0                                                NaN
# 1  Signals and Systems (SAS) - Former organisatio...
# 2  Human Media Interaction - Former organisationa...
# 3                                                NaN
# 4                                                NaN
#
#   11.6 Organisations > Organisational unit[6]  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   11.7 Organisations > Organisational unit[7]  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   11.8 Organisations > Organisational unit[8]  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   11.9 Organisations > Organisational unit[9]
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN

# %%
#Maurice index 113
maurice_row = pure_researchers.iloc[113,]
print(maurice_row)
# Out:
# 1 Name                                                                        Maurice van Keulen
# 2 Name > First name                                                                      Maurice
# 3 Name > Last name                                                                    van Keulen
# 11.1 Organisations > Organisational unit[1]                          Datamanagement & Biometrics
# 11.2 Organisations > Organisational unit[2]                            Digital Society Institute
# 11.3 Organisations > Organisational unit[3]                                       TechMed Centre
# 11.4 Organisations > Organisational unit[4]    Databases (Former) - Former organisational uni...
# 11.5 Organisations > Organisational unit[5]    Databases (Former) - Former organisational uni...
# 11.6 Organisations > Organisational unit[6]    Databases groep - Former organisational unit. ...
# 11.7 Organisations > Organisational unit[7]    Information Systems (IS) - Former organisation...
# 11.8 Organisations > Organisational unit[8]                                                  NaN
# 11.9 Organisations > Organisational unit[9]                                                  NaN
# Name: 113, dtype: object
